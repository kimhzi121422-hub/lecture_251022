# %% [markdown]
# # 14. 그룹화
# ---
# - 동일한 값을 가진 것들끼리 합쳐서 통계 또는 평균 등의 값을 계산하기 위해 사용

# %%
import pandas as pd
df = pd.read_csv('data/customers3.csv', index_col='고객ID')
df

# %% [markdown]
# **`groupby()` 함수**
# - 데이터를 특정 기준에 따라 그룹화하여 집계 연산을 수행한다.
# - 이를 통해 데이터의 패턴을 발견하거나 요약 통계를 얻는 데 매우 유용하다.
# - 기본적인 그룹화`groupby()`는 주어진 열을 기준으로 데이터를 그룹화하고, <br>
#     그 결과에 대해 다양한 집계 연산을 적용할 수 있다

# %%
import pandas as pd

data = {
    '날짜': ['2020-01', '2020-02', '2020-03', '2020-04', '2021-01', '2021-02', '2021-03', '2021-04',
           '2022-01', '2022-02', '2023-01', '2024-01', '2025-01', '2026-01'],
    '생산월': [100, 120, 90, 130, 150, 140, 170, 160, 180, 200, 210, 220, 215, 230],
    '정비확정월': [70, 90, 60, 110, 130, 120, 140, 135, 150, 160, 170, 175, 172, 188]
}
df = pd.DataFrame(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,6))  # 넓고 보기 좋게

# 막대 그래프 (생산월, 파란색)
plt.bar(df['날짜'], df['생산월'], color='royalblue', label='생산월', width=0.6)

# 꺾은선 그래프 (정비확정월, 주황색)
plt.plot(df['날짜'], df['정비확정월'], color='orange', marker='o', linewidth=2, label='정비확정월')

plt.title('월별 생산/정비 집계 비교(2020~2026)')
plt.xlabel('연도-월')
plt.ylabel('수량')
plt.legend(fontsize=13)
plt.grid(axis='y', linestyle='--', alpha=0.4)

# x축 레이블 보기 편하게
plt.xticks(rotation=45, fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# C:\Users\75050\AppData\Local\Temp\ipykernel_6808\3060764977.py:20: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\75050\AppData\Local\Temp\ipykernel_6808\3060764977.py:20: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\75050\AppData\Local\Temp\ipykernel_6808\3060764977.py:20: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\75050\AppData\Local\Temp\ipykernel_6808\3060764977.py:20: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\75050\AppData\Local\Temp\ipykernel_6808\3060764977.py:20: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %% [markdown]
# **`agg()`**
# - 그룹화된 데이터에 대해 원하는 집계 연산을 적용하여 요약 통계를 얻을 수 있다.

# %% [markdown]
# 데이터 집계함수를 사용해보기 위한 DataFrame 수정

# %% [markdown]
# 주요관심사별로 고객만족도와 재구매의사의 최소,최대,총합,평균 계산
